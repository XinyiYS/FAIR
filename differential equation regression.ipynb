# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"

import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf

import numpy as np
from npde_master.utils import gen_data, plot_model, eval_model, em_int
from npde_master.npde_helper import build_model, fit_model, save_model, load_model


import os
from os.path import join as oj
import pandas as pd
import numpy as np
from scipy.stats import sem
from collections import defaultdict

from copy import deepcopy

from utils.utils import cwd, set_up_plotting


import time
import datetime
plt = set_up_plotting()
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/gpflow/session_manager.py:28: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/gpflow/misc.py:24: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/gpflow/training/tensorflow_optimizer.py:151: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
def create_and_fit_model(t, Y, de_type):
    sess = tf.InteractiveSession()
    de_type = de_type.lower()
    if de_type == 'ode':

    # for ode
        npde = build_model(sess, t, Y, model='ode', sf0=1.0, ell0=np.ones(2), W=6, ktype="id")

        prior_sn = npde.sn.eval()
        # print(f'Prior noise variances are {prior_sn}.')

        npde = fit_model(sess, npde, t, Y, num_iter=500, print_every=50, eta=0.02, plot_=False)

        posterior_sn = npde.sn.eval()

    elif de_type == 'vdp':
    # for vdp
        npde = build_model(sess, t, Y, model='sde', sf0=1.0, ell0=np.ones(2), W=6, ellg0=[1e5], ktype="id")

        prior_sn = npde.sn.eval()

        npde = fit_model(sess, npde, t, Y, Nw=100, num_iter=500, print_every=50, eta=0.02, plot_=False)

        posterior_sn = npde.sn.eval()

    elif de_type == 'sde':
    # for sde 
        npde = build_model(sess, t, Y, model='sde', sf0=1.0, ell0=np.ones(2), W=6, ellg0=[1.0], ktype="id", fix_Z=True)

        prior_sn = npde.sn.eval()

        npde = fit_model(sess, npde, t, Y, Nw=50, num_iter=500, print_every=50, eta=0.01, plot_=False)

        posterior_sn = npde.sn.eval()
    
    else:
        raise NotImplementedError(f"DE type: {de_type} not implemented ")

    del sess
    return npde, prior_sn, posterior_sn

def get_times(overall_t, overall_Y, baseline_obs):
    baseline_obs = np.unique(baseline_obs, axis=0)

    baseline_times = []
    baseline_obs_time_synced = []
    for t_i, y_i in zip(overall_t, overall_Y):
        for ob_i in baseline_obs:
            if (y_i == ob_i).all():
                baseline_times.append(t_i)
                baseline_obs_time_synced.append(list(y_i))
                
    baseline_obs_time_synced = np.asarray(baseline_obs_time_synced)
    baseline_times = np.asarray(baseline_times)
    assert len(baseline_times) == len(baseline_obs_time_synced)
    return baseline_times, baseline_obs_time_synced 


def get_rmse(overall_t, overall_Y, baseline_obs, target, de_type):     
    baseline_times, baseline_obs_synced = get_times(overall_t, overall_Y, baseline_obs)
    npde, prior_sn, posterior_sn = create_and_fit_model([baseline_times], [baseline_obs_synced], de_type)
    
    target_times, target_synced = get_times(overall_t, overall_Y, target)
    
    return eval_model(npde, [target_times], [target_synced], Nw=1)

def get_regression_df(mse_results):
    data_df = defaultdict(list)
    for collab_type, mse_list in mse_results.items():
        baseline = collab_type.replace('-avg-mses', '').replace('-mses', '').replace('_obs','')
        if baseline not in data_df['Baselines']:
            data_df['Baselines'].append(baseline)
        if '-avg-mses' in collab_type:
            avg = np.mean(mse_list)
            se = sem(mse_list)
            data_df['Avg MSE'].append(avg)
            data_df['Stderr'].append(se)
        else:
            stds = np.std(mse_list, axis=1)

            mean_std_mse = np.mean(stds)
            se_std_mse = sem(stds)
            data_df['Std MSE'].append(mean_std_mse)
            data_df['Stderr Std'].append(se_std_mse)
    
    return pd.DataFrame(data=data_df)


def get_mses(collab_type, n, overall_t, overall_Y, baseline_obs, Ts, de_type):
    if 'indiv' in collab_type:
        mses = [get_rmse(overall_t, overall_Y, baseline_obs[i], Ts[i], de_type) for i in range(n) ]

    else:
        mses = []

        baseline_obs = np.unique(baseline_obs, axis=0)
        baseline_times, baseline_obs_synced = get_times(overall_t, overall_Y, baseline_obs)
        npde, prior_sn, posterior_sn = create_and_fit_model([baseline_times], [baseline_obs_synced], de_type)
        
        for i, target in enumerate(Ts):
            target = np.unique(target, axis=0)
            target_times, target_synced = get_times(overall_t, overall_Y, target)
            mses.append(eval_model(npde, [target_times], [target_synced], Nw=1))                                   
    return mses

# %%
def run_regression_analysis(de_type='ODE'):
    results_dir = oj('results', 'DE')
    
    with cwd(results_dir):
        result_datas = []
        for file in os.listdir():
            if file.endswith('.npz') and de_type.upper() in file:
                result_datas.append(np.load(file, allow_pickle=True))

        mse_results = defaultdict(list)
        
        for trial_i in range(n_trials):
            print(f'**** trial index {trial_i+1} **** ')
            print()
            obs = result_datas[trial_i]['obs'].item()
            times = result_datas[trial_i]['times']

            overall_t = result_datas[trial_i]['t'][trajectory_index]
            overall_Y = result_datas[trial_i]['Y'][trajectory_index]
            
            Ts = result_datas[trial_i]['Ts']
            for collab_type, baseline_obs in obs.items():   
#                 if 'rand' in collab_type:
                if 'entropy' in collab_type or 'indiv' in collab_type: 
                    try:
                        mses = get_mses(collab_type, n, overall_t, overall_Y, baseline_obs, Ts, de_type)
                        mse = np.mean(mses)

                        ode_mse_results[collab_type+'-avg-mses'].append(mse)        
                        ode_mse_results[collab_type+'-mses'].append(mses)

                        print(f'****** {collab_type} MSEs: {mses} Avg MSE: {mse} ******')
                    except Exception as inst:
                        print(type(inst))    # the exception instance
                        print(inst.args)     # arguments stored in .args
                        print(inst)          # __str__ allows args to be printed directly,
                                             # but may be overridden in exception subclasses

        regression_dir = 'regression_results'
#         os.makedirs(regression_dir)
        
#         time_str = datetime.datetime.fromtimestamp(time.time()).strftime('%m-%d-%H:%M:%S')

#         regression_df = get_regression_df(mse_results)
#         regression_df.to_latex(oj(regression_dir, f'{de_type}-regression-{time_str}.tex'), index=False) 
#         regression_df.to_csv(oj(regression_dir, f'{de_type}-regression-{time_str}.csv'), index=False) 
    return

# %%
n_trials = 5
n = 3
de_type = 'SDE'
trajectory_index = 2

results_dir = oj('results', 'DE')

with cwd(results_dir):
    result_datas = []
    for file in os.listdir():
        if file.endswith('.npz') and de_type.upper() in file:
            result_datas.append(np.load(file, allow_pickle=True))

    mse_results = defaultdict(list)

    for trial_i in range(n_trials):
        print(f'**** trial index {trial_i+1} **** ')
        print()
        obs = result_datas[trial_i]['obs'].item()
        times = result_datas[trial_i]['times']

        overall_t = result_datas[trial_i]['t'][trajectory_index]
        overall_Y = result_datas[trial_i]['Y'][trajectory_index]

        Ts = result_datas[trial_i]['Ts']
        for collab_type, baseline_obs in obs.items():   
                
                if 'indiv' in collab_type:continue 
                try:
                    mses = get_mses(collab_type, n, overall_t, overall_Y, baseline_obs, Ts, de_type)
                    mse = np.mean(mses)

                    mse_results[collab_type+'-avg-mses'].append(mse)        
                    mse_results[collab_type+'-mses'].append(mses)

                    print(f'**** {collab_type} MSEs: {mses} Avg MSE: {mse} ****')
                except Exception as inst:
                    print(type(inst))    # the exception instance
                    print(inst.args)     # arguments stored in .args
                    print(inst)          # __str__ allows args to be printed directly,
                                         # but may be overridden in exception subclasses

    regression_df = get_regression_df(mse_results)
# Out:
# **** trial index 1 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21432883 0.21690132]
# signal variance:       1.3461104682735887
# lengthscales:          [0.9438477  1.08880317]
# diff signal variance:  0.8305085514857685
# diff lengthscales:     [0.89734469]
# RMSE over the dimensions is: 3.9371207460941218
# name:                  npsde
# noise variance:        [0.21432883 0.21690132]
# signal variance:       1.3461104682735887
# lengthscales:          [0.9438477  1.08880317]
# diff signal variance:  0.8305085514857685
# diff lengthscales:     [0.89734469]
# RMSE over the dimensions is: 3.727436095003661
# name:                  npsde
# noise variance:        [0.21432883 0.21690132]
# signal variance:       1.3461104682735887
# lengthscales:          [0.9438477  1.08880317]
# diff signal variance:  0.8305085514857685
# diff lengthscales:     [0.89734469]
# RMSE over the dimensions is: 6.882562789145073
# **** greedy_obs_1 MSEs: [3.9371207460941218, 3.727436095003661, 6.882562789145073] Avg MSE: 4.849039876747619 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21469824 0.21123287]
# signal variance:       1.1180115103091877
# lengthscales:          [0.94662216 1.14066593]
# diff signal variance:  0.8726654401142518
# diff lengthscales:     [0.96067933]
# RMSE over the dimensions is: 3.7546719285084773
# name:                  npsde
# noise variance:        [0.21469824 0.21123287]
# signal variance:       1.1180115103091877
# lengthscales:          [0.94662216 1.14066593]
# diff signal variance:  0.8726654401142518
# diff lengthscales:     [0.96067933]
# RMSE over the dimensions is: 3.8154058355840528
# name:                  npsde
# noise variance:        [0.21469824 0.21123287]
# signal variance:       1.1180115103091877
# lengthscales:          [0.94662216 1.14066593]
# diff signal variance:  0.8726654401142518
# diff lengthscales:     [0.96067933]
# RMSE over the dimensions is: 6.37283873477589
# **** greedy_obs_2 MSEs: [3.7546719285084773, 3.8154058355840528, 6.37283873477589] Avg MSE: 4.64763883295614 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.22520997 0.2205616 ]
# signal variance:       1.1058162214773528
# lengthscales:          [0.98773267 1.05723752]
# diff signal variance:  0.8999157676455367
# diff lengthscales:     [0.94068676]
# RMSE over the dimensions is: 4.229803327857271
# name:                  npsde
# noise variance:        [0.22520997 0.2205616 ]
# signal variance:       1.1058162214773528
# lengthscales:          [0.98773267 1.05723752]
# diff signal variance:  0.8999157676455367
# diff lengthscales:     [0.94068676]
# RMSE over the dimensions is: 3.8138798488252688
# name:                  npsde
# noise variance:        [0.22520997 0.2205616 ]
# signal variance:       1.1058162214773528
# lengthscales:          [0.98773267 1.05723752]
# diff signal variance:  0.8999157676455367
# diff lengthscales:     [0.94068676]
# RMSE over the dimensions is: 6.856487850679862
# **** greedy_obs_3 MSEs: [4.229803327857271, 3.8138798488252688, 6.856487850679862] Avg MSE: 4.966723675787467 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21218455 0.2109741 ]
# signal variance:       1.1869524792911261
# lengthscales:          [0.94565297 1.16041894]
# diff signal variance:  0.8293309101713909
# diff lengthscales:     [0.92584904]
# RMSE over the dimensions is: 3.70625904114334
# name:                  npsde
# noise variance:        [0.21218455 0.2109741 ]
# signal variance:       1.1869524792911261
# lengthscales:          [0.94565297 1.16041894]
# diff signal variance:  0.8293309101713909
# diff lengthscales:     [0.92584904]
# RMSE over the dimensions is: 3.9385932377896404
# name:                  npsde
# noise variance:        [0.21218455 0.2109741 ]
# signal variance:       1.1869524792911261
# lengthscales:          [0.94565297 1.16041894]
# diff signal variance:  0.8293309101713909
# diff lengthscales:     [0.92584904]
# RMSE over the dimensions is: 6.703070658898033
# **** greedy_obs_4 MSEs: [3.70625904114334, 3.9385932377896404, 6.703070658898033] Avg MSE: 4.782640979277004 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21569868 0.21176796]
# signal variance:       1.1189336114814912
# lengthscales:          [1.00776459 1.08946515]
# diff signal variance:  0.869934574023678
# diff lengthscales:     [0.94291251]
# RMSE over the dimensions is: 3.959341067590531
# name:                  npsde
# noise variance:        [0.21569868 0.21176796]
# signal variance:       1.1189336114814912
# lengthscales:          [1.00776459 1.08946515]
# diff signal variance:  0.869934574023678
# diff lengthscales:     [0.94291251]
# RMSE over the dimensions is: 3.730352750774405
# name:                  npsde
# noise variance:        [0.21569868 0.21176796]
# signal variance:       1.1189336114814912
# lengthscales:          [1.00776459 1.08946515]
# diff signal variance:  0.869934574023678
# diff lengthscales:     [0.94291251]
# RMSE over the dimensions is: 6.650311391855747
# **** greedy_sum_obs MSEs: [3.959341067590531, 3.730352750774405, 6.650311391855747] Avg MSE: 4.780001736740228 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21315271 0.21159585]
# signal variance:       1.1307068062594254
# lengthscales:          [0.95188769 1.1136779 ]
# diff signal variance:  0.8572269692742251
# diff lengthscales:     [0.99583286]
# RMSE over the dimensions is: 3.8747221184857095
# name:                  npsde
# noise variance:        [0.21315271 0.21159585]
# signal variance:       1.1307068062594254
# lengthscales:          [0.95188769 1.1136779 ]
# diff signal variance:  0.8572269692742251
# diff lengthscales:     [0.99583286]
# RMSE over the dimensions is: 3.6570728131159043
# name:                  npsde
# noise variance:        [0.21315271 0.21159585]
# signal variance:       1.1307068062594254
# lengthscales:          [0.95188769 1.1136779 ]
# diff signal variance:  0.8572269692742251
# diff lengthscales:     [0.99583286]
# RMSE over the dimensions is: 6.700667986273594
# **** dynamic_beta_obs MSEs: [3.8747221184857095, 3.6570728131159043, 6.700667986273594] Avg MSE: 4.744154305958403 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21231601 0.211573  ]
# signal variance:       1.133527987752562
# lengthscales:          [0.99317111 1.04232777]
# diff signal variance:  0.867431316899961
# diff lengthscales:     [0.96733784]
# RMSE over the dimensions is: 3.9094441638596207
# name:                  npsde
# noise variance:        [0.21231601 0.211573  ]
# signal variance:       1.133527987752562
# lengthscales:          [0.99317111 1.04232777]
# diff signal variance:  0.867431316899961
# diff lengthscales:     [0.96733784]
# RMSE over the dimensions is: 3.957151005677245
# name:                  npsde
# noise variance:        [0.21231601 0.211573  ]
# signal variance:       1.133527987752562
# lengthscales:          [0.99317111 1.04232777]
# diff signal variance:  0.867431316899961
# diff lengthscales:     [0.96733784]
# RMSE over the dimensions is: 6.9135995980375125
# **** joint_obs MSEs: [3.9094441638596207, 3.957151005677245, 6.9135995980375125] Avg MSE: 4.926731589191459 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21085772 0.20742548]
# signal variance:       1.1443748894311505
# lengthscales:          [1.01281477 1.08083825]
# diff signal variance:  0.8403134669510173
# diff lengthscales:     [0.87126878]
# RMSE over the dimensions is: 4.013052048219262
# name:                  npsde
# noise variance:        [0.21085772 0.20742548]
# signal variance:       1.1443748894311505
# lengthscales:          [1.01281477 1.08083825]
# diff signal variance:  0.8403134669510173
# diff lengthscales:     [0.87126878]
# RMSE over the dimensions is: 3.7726927314296503
# name:                  npsde
# noise variance:        [0.21085772 0.20742548]
# signal variance:       1.1443748894311505
# lengthscales:          [1.01281477 1.08083825]
# diff signal variance:  0.8403134669510173
# diff lengthscales:     [0.87126878]
# RMSE over the dimensions is: 6.98800321826565
# **** rand_obs MSEs: [4.013052048219262, 3.7726927314296503, 6.98800321826565] Avg MSE: 4.924582665971521 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.19923394 0.19674557]
# signal variance:       1.2004068980487435
# lengthscales:          [0.82731412 1.18389405]
# diff signal variance:  0.9175167702488756
# diff lengthscales:     [0.98389786]
# RMSE over the dimensions is: 3.5530944321355857
# name:                  npsde
# noise variance:        [0.19923394 0.19674557]
# signal variance:       1.2004068980487435
# lengthscales:          [0.82731412 1.18389405]
# diff signal variance:  0.9175167702488756
# diff lengthscales:     [0.98389786]
# RMSE over the dimensions is: 3.6952728694126726
# name:                  npsde
# noise variance:        [0.19923394 0.19674557]
# signal variance:       1.2004068980487435
# lengthscales:          [0.82731412 1.18389405]
# diff signal variance:  0.9175167702488756
# diff lengthscales:     [0.98389786]
# RMSE over the dimensions is: 3.8258033143334305
# **** entropy_obs MSEs: [3.5530944321355857, 3.6952728694126726, 3.8258033143334305] Avg MSE: 3.6913902052938963 ****
# **** trial index 2 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.428434   0.36865686]
# signal variance:       0.991143585050166
# lengthscales:          [1.00894181 0.97146869]
# diff signal variance:  0.9258303187299289
# diff lengthscales:     [0.99857917]
# RMSE over the dimensions is: 0.7000241681757922
# name:                  npsde
# noise variance:        [0.428434   0.36865686]
# signal variance:       0.991143585050166
# lengthscales:          [1.00894181 0.97146869]
# diff signal variance:  0.9258303187299289
# diff lengthscales:     [0.99857917]
# RMSE over the dimensions is: 3.0120963273736723
# name:                  npsde
# noise variance:        [0.428434   0.36865686]
# signal variance:       0.991143585050166
# lengthscales:          [1.00894181 0.97146869]
# diff signal variance:  0.9258303187299289
# diff lengthscales:     [0.99857917]
# RMSE over the dimensions is: 4.929783565111187
# **** greedy_obs_1 MSEs: [0.7000241681757922, 3.0120963273736723, 4.929783565111187] Avg MSE: 2.8806346868868835 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21016298 0.23619773]
# signal variance:       1.1167607013070122
# lengthscales:          [1.05872961 0.93845748]
# diff signal variance:  0.8532947578290807
# diff lengthscales:     [0.92734998]
# RMSE over the dimensions is: 15.182058119952636
# name:                  npsde
# noise variance:        [0.21016298 0.23619773]
# signal variance:       1.1167607013070122
# lengthscales:          [1.05872961 0.93845748]
# diff signal variance:  0.8532947578290807
# diff lengthscales:     [0.92734998]
# RMSE over the dimensions is: 4.442046215165831
# name:                  npsde
# noise variance:        [0.21016298 0.23619773]
# signal variance:       1.1167607013070122
# lengthscales:          [1.05872961 0.93845748]
# diff signal variance:  0.8532947578290807
# diff lengthscales:     [0.92734998]
# RMSE over the dimensions is: 4.996128640762264
# **** greedy_obs_2 MSEs: [15.182058119952636, 4.442046215165831, 4.996128640762264] Avg MSE: 8.206744325293577 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.22056635 0.21661259]
# signal variance:       1.1578649326860744
# lengthscales:          [0.98546188 1.00033068]
# diff signal variance:  0.8758864702261084
# diff lengthscales:     [0.89229958]
# RMSE over the dimensions is: 0.942525732575727
# name:                  npsde
# noise variance:        [0.22056635 0.21661259]
# signal variance:       1.1578649326860744
# lengthscales:          [0.98546188 1.00033068]
# diff signal variance:  0.8758864702261084
# diff lengthscales:     [0.89229958]
# RMSE over the dimensions is: 3.7088600964850276
# name:                  npsde
# noise variance:        [0.22056635 0.21661259]
# signal variance:       1.1578649326860744
# lengthscales:          [0.98546188 1.00033068]
# diff signal variance:  0.8758864702261084
# diff lengthscales:     [0.89229958]
# RMSE over the dimensions is: 4.934132223540958
# **** greedy_obs_3 MSEs: [0.942525732575727, 3.7088600964850276, 4.934132223540958] Avg MSE: 3.195172684200571 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.24991016 0.21192379]
# signal variance:       1.137123902103656
# lengthscales:          [0.93782477 0.99363009]
# diff signal variance:  0.8949817144533216
# diff lengthscales:     [0.88706898]
# RMSE over the dimensions is: 0.8640490660132585
# name:                  npsde
# noise variance:        [0.24991016 0.21192379]
# signal variance:       1.137123902103656
# lengthscales:          [0.93782477 0.99363009]
# diff signal variance:  0.8949817144533216
# diff lengthscales:     [0.88706898]
# RMSE over the dimensions is: 4.383611650907755
# name:                  npsde
# noise variance:        [0.24991016 0.21192379]
# signal variance:       1.137123902103656
# lengthscales:          [0.93782477 0.99363009]
# diff signal variance:  0.8949817144533216
# diff lengthscales:     [0.88706898]
# RMSE over the dimensions is: 5.376546378262279
# **** greedy_obs_4 MSEs: [0.8640490660132585, 4.383611650907755, 5.376546378262279] Avg MSE: 3.5414023650610975 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.22214575 0.21806375]
# signal variance:       1.1466323274538124
# lengthscales:          [0.98187628 0.97106297]
# diff signal variance:  0.9116683523133863
# diff lengthscales:     [0.97137787]
# RMSE over the dimensions is: 9.569878122663559
# name:                  npsde
# noise variance:        [0.22214575 0.21806375]
# signal variance:       1.1466323274538124
# lengthscales:          [0.98187628 0.97106297]
# diff signal variance:  0.9116683523133863
# diff lengthscales:     [0.97137787]
# RMSE over the dimensions is: 0.35752572624779017
# name:                  npsde
# noise variance:        [0.22214575 0.21806375]
# signal variance:       1.1466323274538124
# lengthscales:          [0.98187628 0.97106297]
# diff signal variance:  0.9116683523133863
# diff lengthscales:     [0.97137787]
# RMSE over the dimensions is: 5.339784635000643
# **** greedy_sum_obs MSEs: [9.569878122663559, 0.35752572624779017, 5.339784635000643] Avg MSE: 5.089062827970664 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.4376177  0.29733927]
# signal variance:       1.0693757514743505
# lengthscales:          [0.95453221 0.97253413]
# diff signal variance:  0.9173397995006899
# diff lengthscales:     [0.93131455]
# RMSE over the dimensions is: 0.6110410492625463
# name:                  npsde
# noise variance:        [0.4376177  0.29733927]
# signal variance:       1.0693757514743505
# lengthscales:          [0.95453221 0.97253413]
# diff signal variance:  0.9173397995006899
# diff lengthscales:     [0.93131455]
# RMSE over the dimensions is: 3.047201460356969
# name:                  npsde
# noise variance:        [0.4376177  0.29733927]
# signal variance:       1.0693757514743505
# lengthscales:          [0.95453221 0.97253413]
# diff signal variance:  0.9173397995006899
# diff lengthscales:     [0.93131455]
# RMSE over the dimensions is: 5.5149382389438895
# **** dynamic_beta_obs MSEs: [0.6110410492625463, 3.047201460356969, 5.5149382389438895] Avg MSE: 3.0577269161878013 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.44529949 0.22596995]
# signal variance:       1.0481407698694447
# lengthscales:          [1.01529337 0.95894985]
# diff signal variance:  0.9040212215862713
# diff lengthscales:     [0.9649967]
# RMSE over the dimensions is: 1.110862418175462
# name:                  npsde
# noise variance:        [0.44529949 0.22596995]
# signal variance:       1.0481407698694447
# lengthscales:          [1.01529337 0.95894985]
# diff signal variance:  0.9040212215862713
# diff lengthscales:     [0.9649967]
# RMSE over the dimensions is: 11.52559638870333
# name:                  npsde
# noise variance:        [0.44529949 0.22596995]
# signal variance:       1.0481407698694447
# lengthscales:          [1.01529337 0.95894985]
# diff signal variance:  0.9040212215862713
# diff lengthscales:     [0.9649967]
# RMSE over the dimensions is: 5.525628959314423
# **** joint_obs MSEs: [1.110862418175462, 11.52559638870333, 5.525628959314423] Avg MSE: 6.0540292553977375 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.23175254 0.20611855]
# signal variance:       1.1357973867002917
# lengthscales:          [0.98942398 0.99413138]
# diff signal variance:  0.875374647896645
# diff lengthscales:     [0.99533494]
# RMSE over the dimensions is: 1.2042883238886188
# name:                  npsde
# noise variance:        [0.23175254 0.20611855]
# signal variance:       1.1357973867002917
# lengthscales:          [0.98942398 0.99413138]
# diff signal variance:  0.875374647896645
# diff lengthscales:     [0.99533494]
# RMSE over the dimensions is: 3.6286560935167413
# name:                  npsde
# noise variance:        [0.23175254 0.20611855]
# signal variance:       1.1357973867002917
# lengthscales:          [0.98942398 0.99413138]
# diff signal variance:  0.875374647896645
# diff lengthscales:     [0.99533494]
# RMSE over the dimensions is: 5.310981714190368
# **** rand_obs MSEs: [1.2042883238886188, 3.6286560935167413, 5.310981714190368] Avg MSE: 3.3813087105319095 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.20863748 0.21725174]
# signal variance:       1.1477314635831344
# lengthscales:          [0.94050495 1.01581187]
# diff signal variance:  0.8889113278611778
# diff lengthscales:     [0.9523598]
# RMSE over the dimensions is: 0.622640541264697
# name:                  npsde
# noise variance:        [0.20863748 0.21725174]
# signal variance:       1.1477314635831344
# lengthscales:          [0.94050495 1.01581187]
# diff signal variance:  0.8889113278611778
# diff lengthscales:     [0.9523598]
# RMSE over the dimensions is: 1.1762722185470935
# name:                  npsde
# noise variance:        [0.20863748 0.21725174]
# signal variance:       1.1477314635831344
# lengthscales:          [0.94050495 1.01581187]
# diff signal variance:  0.8889113278611778
# diff lengthscales:     [0.9523598]
# RMSE over the dimensions is: 3.7313875435135078
# **** entropy_obs MSEs: [0.622640541264697, 1.1762722185470935, 3.7313875435135078] Avg MSE: 1.843433434441766 ****
# **** trial index 3 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.34830995 0.33638878]
# signal variance:       1.0980732521910053
# lengthscales:          [0.95229214 0.97894917]
# diff signal variance:  0.8952080521730112
# diff lengthscales:     [0.89566725]
# RMSE over the dimensions is: 3.536814682517542
# name:                  npsde
# noise variance:        [0.34830995 0.33638878]
# signal variance:       1.0980732521910053
# lengthscales:          [0.95229214 0.97894917]
# diff signal variance:  0.8952080521730112
# diff lengthscales:     [0.89566725]
# RMSE over the dimensions is: 4.866610861566275
# name:                  npsde
# noise variance:        [0.34830995 0.33638878]
# signal variance:       1.0980732521910053
# lengthscales:          [0.95229214 0.97894917]
# diff signal variance:  0.8952080521730112
# diff lengthscales:     [0.89566725]
# RMSE over the dimensions is: 6.088167390640395
# **** greedy_obs_1 MSEs: [3.536814682517542, 4.866610861566275, 6.088167390640395] Avg MSE: 4.830530978241404 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.22469092 0.26696415]
# signal variance:       1.0736921332455671
# lengthscales:          [1.00227351 1.00944793]
# diff signal variance:  0.8897039796546168
# diff lengthscales:     [0.93801175]
# RMSE over the dimensions is: 4.017329541211567
# name:                  npsde
# noise variance:        [0.22469092 0.26696415]
# signal variance:       1.0736921332455671
# lengthscales:          [1.00227351 1.00944793]
# diff signal variance:  0.8897039796546168
# diff lengthscales:     [0.93801175]
# RMSE over the dimensions is: 3.706809095418585
# name:                  npsde
# noise variance:        [0.22469092 0.26696415]
# signal variance:       1.0736921332455671
# lengthscales:          [1.00227351 1.00944793]
# diff signal variance:  0.8897039796546168
# diff lengthscales:     [0.93801175]
# RMSE over the dimensions is: 5.814971388846773
# **** greedy_obs_2 MSEs: [4.017329541211567, 3.706809095418585, 5.814971388846773] Avg MSE: 4.513036675158975 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.22949028 0.25756147]
# signal variance:       1.1141679271697797
# lengthscales:          [0.94484716 0.98434759]
# diff signal variance:  0.893923429776239
# diff lengthscales:     [0.88703754]
# RMSE over the dimensions is: 3.46011290857738
# name:                  npsde
# noise variance:        [0.22949028 0.25756147]
# signal variance:       1.1141679271697797
# lengthscales:          [0.94484716 0.98434759]
# diff signal variance:  0.893923429776239
# diff lengthscales:     [0.88703754]
# RMSE over the dimensions is: 4.460269604746667
# name:                  npsde
# noise variance:        [0.22949028 0.25756147]
# signal variance:       1.1141679271697797
# lengthscales:          [0.94484716 0.98434759]
# diff signal variance:  0.893923429776239
# diff lengthscales:     [0.88703754]
# RMSE over the dimensions is: 5.562736658266122
# **** greedy_obs_3 MSEs: [3.46011290857738, 4.460269604746667, 5.562736658266122] Avg MSE: 4.494373057196722 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21702823 0.24140233]
# signal variance:       1.0729666978254884
# lengthscales:          [0.98787918 1.00036054]
# diff signal variance:  0.9097305235075503
# diff lengthscales:     [0.91328077]
# RMSE over the dimensions is: 3.661954815938614
# name:                  npsde
# noise variance:        [0.21702823 0.24140233]
# signal variance:       1.0729666978254884
# lengthscales:          [0.98787918 1.00036054]
# diff signal variance:  0.9097305235075503
# diff lengthscales:     [0.91328077]
# RMSE over the dimensions is: 4.891401275367892
# name:                  npsde
# noise variance:        [0.21702823 0.24140233]
# signal variance:       1.0729666978254884
# lengthscales:          [0.98787918 1.00036054]
# diff signal variance:  0.9097305235075503
# diff lengthscales:     [0.91328077]
# RMSE over the dimensions is: 4.952816314789905
# **** greedy_obs_4 MSEs: [3.661954815938614, 4.891401275367892, 4.952816314789905] Avg MSE: 4.502057468698804 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.28958001 0.31864997]
# signal variance:       1.0493953926052533
# lengthscales:          [0.97301814 0.954996  ]
# diff signal variance:  0.895229121453946
# diff lengthscales:     [0.82685987]
# RMSE over the dimensions is: 1.8862600200566044
# name:                  npsde
# noise variance:        [0.28958001 0.31864997]
# signal variance:       1.0493953926052533
# lengthscales:          [0.97301814 0.954996  ]
# diff signal variance:  0.895229121453946
# diff lengthscales:     [0.82685987]
# RMSE over the dimensions is: 3.9162657728227326
# name:                  npsde
# noise variance:        [0.28958001 0.31864997]
# signal variance:       1.0493953926052533
# lengthscales:          [0.97301814 0.954996  ]
# diff signal variance:  0.895229121453946
# diff lengthscales:     [0.82685987]
# RMSE over the dimensions is: 5.778977474660696
# **** greedy_sum_obs MSEs: [1.8862600200566044, 3.9162657728227326, 5.778977474660696] Avg MSE: 3.8605010891800107 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.36564136 0.33380581]
# signal variance:       1.0016019082474852
# lengthscales:          [0.98228447 0.94484393]
# diff signal variance:  0.8682850818432226
# diff lengthscales:     [0.90449128]
# RMSE over the dimensions is: 1.8835956378644427
# name:                  npsde
# noise variance:        [0.36564136 0.33380581]
# signal variance:       1.0016019082474852
# lengthscales:          [0.98228447 0.94484393]
# diff signal variance:  0.8682850818432226
# diff lengthscales:     [0.90449128]
# RMSE over the dimensions is: 3.6380733601024495
# name:                  npsde
# noise variance:        [0.36564136 0.33380581]
# signal variance:       1.0016019082474852
# lengthscales:          [0.98228447 0.94484393]
# diff signal variance:  0.8682850818432226
# diff lengthscales:     [0.90449128]
# RMSE over the dimensions is: 5.582340428690979
# **** dynamic_beta_obs MSEs: [1.8835956378644427, 3.6380733601024495, 5.582340428690979] Avg MSE: 3.701336475552624 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.26467205 0.28521398]
# signal variance:       1.1122449052235805
# lengthscales:          [0.97895001 0.97658206]
# diff signal variance:  0.8529458197565757
# diff lengthscales:     [0.91671591]
# RMSE over the dimensions is: 4.55427859985833
# name:                  npsde
# noise variance:        [0.26467205 0.28521398]
# signal variance:       1.1122449052235805
# lengthscales:          [0.97895001 0.97658206]
# diff signal variance:  0.8529458197565757
# diff lengthscales:     [0.91671591]
# RMSE over the dimensions is: 4.12596764301938
# name:                  npsde
# noise variance:        [0.26467205 0.28521398]
# signal variance:       1.1122449052235805
# lengthscales:          [0.97895001 0.97658206]
# diff signal variance:  0.8529458197565757
# diff lengthscales:     [0.91671591]
# RMSE over the dimensions is: 5.611719589349503
# **** joint_obs MSEs: [4.55427859985833, 4.12596764301938, 5.611719589349503] Avg MSE: 4.7639886107424045 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.31221131 0.37734023]
# signal variance:       0.9964744622198347
# lengthscales:          [0.94512368 0.94964972]
# diff signal variance:  0.9122568155837013
# diff lengthscales:     [0.90405052]
# RMSE over the dimensions is: 1.4777401199103668
# name:                  npsde
# noise variance:        [0.31221131 0.37734023]
# signal variance:       0.9964744622198347
# lengthscales:          [0.94512368 0.94964972]
# diff signal variance:  0.9122568155837013
# diff lengthscales:     [0.90405052]
# RMSE over the dimensions is: 2.5590892468007413
# name:                  npsde
# noise variance:        [0.31221131 0.37734023]
# signal variance:       0.9964744622198347
# lengthscales:          [0.94512368 0.94964972]
# diff signal variance:  0.9122568155837013
# diff lengthscales:     [0.90405052]
# RMSE over the dimensions is: 3.5465794434146707
# **** rand_obs MSEs: [1.4777401199103668, 2.5590892468007413, 3.5465794434146707] Avg MSE: 2.5278029367085932 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.3713195  0.42399128]
# signal variance:       1.012821240672298
# lengthscales:          [0.93168664 0.97824248]
# diff signal variance:  0.9130676070568078
# diff lengthscales:     [0.90404079]
# RMSE over the dimensions is: 4.4576424309071
# name:                  npsde
# noise variance:        [0.3713195  0.42399128]
# signal variance:       1.012821240672298
# lengthscales:          [0.93168664 0.97824248]
# diff signal variance:  0.9130676070568078
# diff lengthscales:     [0.90404079]
# RMSE over the dimensions is: 4.330893446777028
# name:                  npsde
# noise variance:        [0.3713195  0.42399128]
# signal variance:       1.012821240672298
# lengthscales:          [0.93168664 0.97824248]
# diff signal variance:  0.9130676070568078
# diff lengthscales:     [0.90404079]
# RMSE over the dimensions is: 2.6271151259490195
# **** entropy_obs MSEs: [4.4576424309071, 4.330893446777028, 2.6271151259490195] Avg MSE: 3.8052170012110498 ****
# **** trial index 4 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.31586665 0.23657201]
# signal variance:       1.0631392381499847
# lengthscales:          [0.97240095 1.03004017]
# diff signal variance:  0.9040449583799945
# diff lengthscales:     [0.94185912]
# RMSE over the dimensions is: 1.2948294571940437
# name:                  npsde
# noise variance:        [0.31586665 0.23657201]
# signal variance:       1.0631392381499847
# lengthscales:          [0.97240095 1.03004017]
# diff signal variance:  0.9040449583799945
# diff lengthscales:     [0.94185912]
# RMSE over the dimensions is: 2.4876888400853177
# name:                  npsde
# noise variance:        [0.31586665 0.23657201]
# signal variance:       1.0631392381499847
# lengthscales:          [0.97240095 1.03004017]
# diff signal variance:  0.9040449583799945
# diff lengthscales:     [0.94185912]
# RMSE over the dimensions is: 5.567451333658423
# **** greedy_obs_1 MSEs: [1.2948294571940437, 2.4876888400853177, 5.567451333658423] Avg MSE: 3.1166565436459286 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.25947956 0.23508892]
# signal variance:       1.0768442539421483
# lengthscales:          [0.99286872 1.00233859]
# diff signal variance:  0.8906127161804316
# diff lengthscales:     [0.89455494]
# RMSE over the dimensions is: 1.4844439985077853
# name:                  npsde
# noise variance:        [0.25947956 0.23508892]
# signal variance:       1.0768442539421483
# lengthscales:          [0.99286872 1.00233859]
# diff signal variance:  0.8906127161804316
# diff lengthscales:     [0.89455494]
# RMSE over the dimensions is: 5.029718454541945
# name:                  npsde
# noise variance:        [0.25947956 0.23508892]
# signal variance:       1.0768442539421483
# lengthscales:          [0.99286872 1.00233859]
# diff signal variance:  0.8906127161804316
# diff lengthscales:     [0.89455494]
# RMSE over the dimensions is: 5.477704251460688
# **** greedy_obs_2 MSEs: [1.4844439985077853, 5.029718454541945, 5.477704251460688] Avg MSE: 3.9972889015034725 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.30234864 0.25267731]
# signal variance:       1.064161226478547
# lengthscales:          [0.98033565 1.0862334 ]
# diff signal variance:  0.8984846858525904
# diff lengthscales:     [0.93914007]
# RMSE over the dimensions is: 2.1752160222346886
# name:                  npsde
# noise variance:        [0.30234864 0.25267731]
# signal variance:       1.064161226478547
# lengthscales:          [0.98033565 1.0862334 ]
# diff signal variance:  0.8984846858525904
# diff lengthscales:     [0.93914007]
# RMSE over the dimensions is: 3.853646194984521
# name:                  npsde
# noise variance:        [0.30234864 0.25267731]
# signal variance:       1.064161226478547
# lengthscales:          [0.98033565 1.0862334 ]
# diff signal variance:  0.8984846858525904
# diff lengthscales:     [0.93914007]
# RMSE over the dimensions is: 5.574434913676644
# **** greedy_obs_3 MSEs: [2.1752160222346886, 3.853646194984521, 5.574434913676644] Avg MSE: 3.867765710298618 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.37924809 0.28931748]
# signal variance:       1.0527942617252333
# lengthscales:          [0.97798583 1.07208792]
# diff signal variance:  0.901964461684449
# diff lengthscales:     [0.92870097]
# RMSE over the dimensions is: 3.9039624129638466
# name:                  npsde
# noise variance:        [0.37924809 0.28931748]
# signal variance:       1.0527942617252333
# lengthscales:          [0.97798583 1.07208792]
# diff signal variance:  0.901964461684449
# diff lengthscales:     [0.92870097]
# RMSE over the dimensions is: 2.3784628341723892
# name:                  npsde
# noise variance:        [0.37924809 0.28931748]
# signal variance:       1.0527942617252333
# lengthscales:          [0.97798583 1.07208792]
# diff signal variance:  0.901964461684449
# diff lengthscales:     [0.92870097]
# RMSE over the dimensions is: 5.706474087001787
# **** greedy_obs_4 MSEs: [3.9039624129638466, 2.3784628341723892, 5.706474087001787] Avg MSE: 3.9962997780460072 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.29103029 0.2492158 ]
# signal variance:       1.0603603986755608
# lengthscales:          [0.97195122 1.05409362]
# diff signal variance:  0.9129509088126603
# diff lengthscales:     [0.93035488]
# RMSE over the dimensions is: 1.4334227816767913
# name:                  npsde
# noise variance:        [0.29103029 0.2492158 ]
# signal variance:       1.0603603986755608
# lengthscales:          [0.97195122 1.05409362]
# diff signal variance:  0.9129509088126603
# diff lengthscales:     [0.93035488]
# RMSE over the dimensions is: 1.4440884530002591
# name:                  npsde
# noise variance:        [0.29103029 0.2492158 ]
# signal variance:       1.0603603986755608
# lengthscales:          [0.97195122 1.05409362]
# diff signal variance:  0.9129509088126603
# diff lengthscales:     [0.93035488]
# RMSE over the dimensions is: 5.589315402117044
# **** greedy_sum_obs MSEs: [1.4334227816767913, 1.4440884530002591, 5.589315402117044] Avg MSE: 2.8222755455980315 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.2636935  0.21829031]
# signal variance:       1.111580468796749
# lengthscales:          [0.97448388 1.01671911]
# diff signal variance:  0.8911571777919253
# diff lengthscales:     [0.90656495]
# RMSE over the dimensions is: 1.3683429054025158
# name:                  npsde
# noise variance:        [0.2636935  0.21829031]
# signal variance:       1.111580468796749
# lengthscales:          [0.97448388 1.01671911]
# diff signal variance:  0.8911571777919253
# diff lengthscales:     [0.90656495]
# RMSE over the dimensions is: 3.3205586063073094
# name:                  npsde
# noise variance:        [0.2636935  0.21829031]
# signal variance:       1.111580468796749
# lengthscales:          [0.97448388 1.01671911]
# diff signal variance:  0.8911571777919253
# diff lengthscales:     [0.90656495]
# RMSE over the dimensions is: 5.516102015650242
# **** dynamic_beta_obs MSEs: [1.3683429054025158, 3.3205586063073094, 5.516102015650242] Avg MSE: 3.4016678424533553 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.46384484 0.30355221]
# signal variance:       0.9166913005312602
# lengthscales:          [0.98964753 0.9971699 ]
# diff signal variance:  1.026737525331274
# diff lengthscales:     [1.00446588]
# RMSE over the dimensions is: 0.8454079174503026
# name:                  npsde
# noise variance:        [0.46384484 0.30355221]
# signal variance:       0.9166913005312602
# lengthscales:          [0.98964753 0.9971699 ]
# diff signal variance:  1.026737525331274
# diff lengthscales:     [1.00446588]
# RMSE over the dimensions is: 19.51113572605341
# name:                  npsde
# noise variance:        [0.46384484 0.30355221]
# signal variance:       0.9166913005312602
# lengthscales:          [0.98964753 0.9971699 ]
# diff signal variance:  1.026737525331274
# diff lengthscales:     [1.00446588]
# RMSE over the dimensions is: 5.1647216463036125
# **** joint_obs MSEs: [0.8454079174503026, 19.51113572605341, 5.1647216463036125] Avg MSE: 8.507088429935775 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21152    0.21261237]
# signal variance:       1.2412632683532248
# lengthscales:          [1.06043996 1.11968605]
# diff signal variance:  0.8598871896898969
# diff lengthscales:     [0.96209487]
# RMSE over the dimensions is: 2.4756183413369635
# name:                  npsde
# noise variance:        [0.21152    0.21261237]
# signal variance:       1.2412632683532248
# lengthscales:          [1.06043996 1.11968605]
# diff signal variance:  0.8598871896898969
# diff lengthscales:     [0.96209487]
# RMSE over the dimensions is: 5.037075537332197
# name:                  npsde
# noise variance:        [0.21152    0.21261237]
# signal variance:       1.2412632683532248
# lengthscales:          [1.06043996 1.11968605]
# diff signal variance:  0.8598871896898969
# diff lengthscales:     [0.96209487]
# RMSE over the dimensions is: 5.530625965655741
# **** rand_obs MSEs: [2.4756183413369635, 5.037075537332197, 5.530625965655741] Avg MSE: 4.347773281441634 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.3208733  0.22656095]
# signal variance:       1.217216366037427
# lengthscales:          [0.95599974 1.16689972]
# diff signal variance:  0.8571701706738243
# diff lengthscales:     [0.89393564]
# RMSE over the dimensions is: 2.438476112528729
# name:                  npsde
# noise variance:        [0.3208733  0.22656095]
# signal variance:       1.217216366037427
# lengthscales:          [0.95599974 1.16689972]
# diff signal variance:  0.8571701706738243
# diff lengthscales:     [0.89393564]
# RMSE over the dimensions is: 3.577536412795877
# name:                  npsde
# noise variance:        [0.3208733  0.22656095]
# signal variance:       1.217216366037427
# lengthscales:          [0.95599974 1.16689972]
# diff signal variance:  0.8571701706738243
# diff lengthscales:     [0.89393564]
# RMSE over the dimensions is: 2.8017639251073163
# **** entropy_obs MSEs: [2.438476112528729, 3.577536412795877, 2.8017639251073163] Avg MSE: 2.9392588168106406 ****
# **** trial index 5 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.2327096  0.23431887]
# signal variance:       1.0424569690214485
# lengthscales:          [0.98459676 1.08246447]
# diff signal variance:  0.9126663280814592
# diff lengthscales:     [0.936379]
# RMSE over the dimensions is: 4.494106614129199
# name:                  npsde
# noise variance:        [0.2327096  0.23431887]
# signal variance:       1.0424569690214485
# lengthscales:          [0.98459676 1.08246447]
# diff signal variance:  0.9126663280814592
# diff lengthscales:     [0.936379]
# RMSE over the dimensions is: 2.0943330872399697
# name:                  npsde
# noise variance:        [0.2327096  0.23431887]
# signal variance:       1.0424569690214485
# lengthscales:          [0.98459676 1.08246447]
# diff signal variance:  0.9126663280814592
# diff lengthscales:     [0.936379]
# RMSE over the dimensions is: 5.80130404724847
# **** greedy_obs_1 MSEs: [4.494106614129199, 2.0943330872399697, 5.80130404724847] Avg MSE: 4.129914582872547 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.22666727 0.22609526]
# signal variance:       1.0534070303713188
# lengthscales:          [0.98333247 1.18563279]
# diff signal variance:  0.9081762087603383
# diff lengthscales:     [0.93018924]
# RMSE over the dimensions is: 4.516787138281382
# name:                  npsde
# noise variance:        [0.22666727 0.22609526]
# signal variance:       1.0534070303713188
# lengthscales:          [0.98333247 1.18563279]
# diff signal variance:  0.9081762087603383
# diff lengthscales:     [0.93018924]
# RMSE over the dimensions is: 2.563893611961305
# name:                  npsde
# noise variance:        [0.22666727 0.22609526]
# signal variance:       1.0534070303713188
# lengthscales:          [0.98333247 1.18563279]
# diff signal variance:  0.9081762087603383
# diff lengthscales:     [0.93018924]
# RMSE over the dimensions is: 5.523109053964598
# **** greedy_obs_2 MSEs: [4.516787138281382, 2.563893611961305, 5.523109053964598] Avg MSE: 4.201263268069095 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.20700499 0.20856676]
# signal variance:       1.1252748549023353
# lengthscales:          [0.96814028 1.16878999]
# diff signal variance:  0.8783338550923392
# diff lengthscales:     [0.89316548]
# RMSE over the dimensions is: 4.46682684440744
# name:                  npsde
# noise variance:        [0.20700499 0.20856676]
# signal variance:       1.1252748549023353
# lengthscales:          [0.96814028 1.16878999]
# diff signal variance:  0.8783338550923392
# diff lengthscales:     [0.89316548]
# RMSE over the dimensions is: 2.4023331740922123
# name:                  npsde
# noise variance:        [0.20700499 0.20856676]
# signal variance:       1.1252748549023353
# lengthscales:          [0.96814028 1.16878999]
# diff signal variance:  0.8783338550923392
# diff lengthscales:     [0.89316548]
# RMSE over the dimensions is: 5.6401787145279965
# **** greedy_obs_3 MSEs: [4.46682684440744, 2.4023331740922123, 5.6401787145279965] Avg MSE: 4.169779577675883 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21967694 0.22667691]
# signal variance:       1.0443692774680156
# lengthscales:          [0.92933876 1.11158683]
# diff signal variance:  0.9006970515636502
# diff lengthscales:     [0.94058741]
# RMSE over the dimensions is: 4.793669504809245
# name:                  npsde
# noise variance:        [0.21967694 0.22667691]
# signal variance:       1.0443692774680156
# lengthscales:          [0.92933876 1.11158683]
# diff signal variance:  0.9006970515636502
# diff lengthscales:     [0.94058741]
# RMSE over the dimensions is: 3.012583876776012
# name:                  npsde
# noise variance:        [0.21967694 0.22667691]
# signal variance:       1.0443692774680156
# lengthscales:          [0.92933876 1.11158683]
# diff signal variance:  0.9006970515636502
# diff lengthscales:     [0.94058741]
# RMSE over the dimensions is: 4.703343297543731
# **** greedy_obs_4 MSEs: [4.793669504809245, 3.012583876776012, 4.703343297543731] Avg MSE: 4.169865559709662 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.2136696  0.21281645]
# signal variance:       1.2489845530355632
# lengthscales:          [1.0015429  1.06996734]
# diff signal variance:  0.8063622994251127
# diff lengthscales:     [0.91361652]
# RMSE over the dimensions is: 3.9621754653047887
# name:                  npsde
# noise variance:        [0.2136696  0.21281645]
# signal variance:       1.2489845530355632
# lengthscales:          [1.0015429  1.06996734]
# diff signal variance:  0.8063622994251127
# diff lengthscales:     [0.91361652]
# RMSE over the dimensions is: 2.865779493798144
# name:                  npsde
# noise variance:        [0.2136696  0.21281645]
# signal variance:       1.2489845530355632
# lengthscales:          [1.0015429  1.06996734]
# diff signal variance:  0.8063622994251127
# diff lengthscales:     [0.91361652]
# RMSE over the dimensions is: 4.960114907337439
# **** greedy_sum_obs MSEs: [3.9621754653047887, 2.865779493798144, 4.960114907337439] Avg MSE: 3.92935662214679 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.20587352 0.20636785]
# signal variance:       1.124123374975039
# lengthscales:          [1.00480704 1.11457941]
# diff signal variance:  0.8457641374205185
# diff lengthscales:     [0.89365682]
# RMSE over the dimensions is: 4.430388157457864
# name:                  npsde
# noise variance:        [0.20587352 0.20636785]
# signal variance:       1.124123374975039
# lengthscales:          [1.00480704 1.11457941]
# diff signal variance:  0.8457641374205185
# diff lengthscales:     [0.89365682]
# RMSE over the dimensions is: 2.471906799321776
# name:                  npsde
# noise variance:        [0.20587352 0.20636785]
# signal variance:       1.124123374975039
# lengthscales:          [1.00480704 1.11457941]
# diff signal variance:  0.8457641374205185
# diff lengthscales:     [0.89365682]
# RMSE over the dimensions is: 5.268602359497146
# **** dynamic_beta_obs MSEs: [4.430388157457864, 2.471906799321776, 5.268602359497146] Avg MSE: 4.056965772092262 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.2261563  0.23203902]
# signal variance:       1.034864065278786
# lengthscales:          [0.99269104 1.12650685]
# diff signal variance:  0.9017543625438613
# diff lengthscales:     [0.92166591]
# RMSE over the dimensions is: 4.4893426421978715
# name:                  npsde
# noise variance:        [0.2261563  0.23203902]
# signal variance:       1.034864065278786
# lengthscales:          [0.99269104 1.12650685]
# diff signal variance:  0.9017543625438613
# diff lengthscales:     [0.92166591]
# RMSE over the dimensions is: 2.5308548094227037
# name:                  npsde
# noise variance:        [0.2261563  0.23203902]
# signal variance:       1.034864065278786
# lengthscales:          [0.99269104 1.12650685]
# diff signal variance:  0.9017543625438613
# diff lengthscales:     [0.92166591]
# RMSE over the dimensions is: 5.410478244493175
# **** joint_obs MSEs: [4.4893426421978715, 2.5308548094227037, 5.410478244493175] Avg MSE: 4.14355856537125 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.21211275 0.21415108]
# signal variance:       1.1164535684099994
# lengthscales:          [0.95538238 1.20317678]
# diff signal variance:  0.894982999118357
# diff lengthscales:     [0.90436158]
# RMSE over the dimensions is: 3.974530994283291
# name:                  npsde
# noise variance:        [0.21211275 0.21415108]
# signal variance:       1.1164535684099994
# lengthscales:          [0.95538238 1.20317678]
# diff signal variance:  0.894982999118357
# diff lengthscales:     [0.90436158]
# RMSE over the dimensions is: 3.071304769114967
# name:                  npsde
# noise variance:        [0.21211275 0.21415108]
# signal variance:       1.1164535684099994
# lengthscales:          [0.95538238 1.20317678]
# diff signal variance:  0.894982999118357
# diff lengthscales:     [0.90436158]
# RMSE over the dimensions is: 4.962796759807645
# **** rand_obs MSEs: [3.974530994283291, 3.071304769114967, 4.962796759807645] Avg MSE: 4.002877507735302 ****
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npsde
# noise variance:        [0.20884595 0.22924298]
# signal variance:       1.1908735498131662
# lengthscales:          [0.98995211 1.24006819]
# diff signal variance:  0.7624261714358949
# diff lengthscales:     [0.99855377]
# RMSE over the dimensions is: 4.951289621187042
# name:                  npsde
# noise variance:        [0.20884595 0.22924298]
# signal variance:       1.1908735498131662
# lengthscales:          [0.98995211 1.24006819]
# diff signal variance:  0.7624261714358949
# diff lengthscales:     [0.99855377]
# RMSE over the dimensions is: 3.5623577652919303
# name:                  npsde
# noise variance:        [0.20884595 0.22924298]
# signal variance:       1.1908735498131662
# lengthscales:          [0.98995211 1.24006819]
# diff signal variance:  0.7624261714358949
# diff lengthscales:     [0.99855377]
# RMSE over the dimensions is: 5.077343687171046
# **** entropy_obs MSEs: [4.951289621187042, 3.5623577652919303, 5.077343687171046] Avg MSE: 4.530330357883339 ****

# %%
regression_df
# Out:
#       Baselines   Avg MSE    Stderr   Std MSE  Stderr Std
# 0      greedy_1  3.961355  0.415532  1.509374    0.133572
# 1      greedy_2  5.113194  0.781788  2.020337    0.742366
# 2      greedy_3  4.138763  0.298056  1.320298    0.130503
# 3      greedy_4  4.198453  0.212938  1.214258    0.234954
# 4    greedy_sum  4.096240  0.397469  1.898504    0.499957
# 5  dynamic_beta  3.792370  0.289529  1.553035    0.140785
# 6         joint  5.679079  0.771345  3.095353    1.374249
# 7          rand  3.836869  0.411879  1.220882    0.177586
# 8       entropy  3.361926  0.455779  0.692293    0.205279

# %%
n_trials = 5
n = 3
de_type = 'ODE'
trajectory_index = 2

results_dir = oj('results', 'DE')

with cwd(results_dir):
    result_datas = []
    for file in os.listdir():
        if file.endswith('.npz') and de_type.upper() in file:
            result_datas.append(np.load(file, allow_pickle=True))

    mse_results = defaultdict(list)

    for trial_i in range(n_trials):
        print(f'**** trial index {trial_i+1} **** ')
        print()
        obs = result_datas[trial_i]['obs'].item()
        times = result_datas[trial_i]['times']

        overall_t = result_datas[trial_i]['t'][trajectory_index]
        overall_Y = result_datas[trial_i]['Y'][trajectory_index]

        Ts = result_datas[trial_i]['Ts']
        for collab_type, baseline_obs in obs.items():   
                
            if 'indiv' in collab_type: 
                try:
                    mses = get_mses(collab_type, n, overall_t, overall_Y, baseline_obs, Ts, de_type)
                    mse = np.mean(mses)

                    mse_results[collab_type+'-avg-mses'].append(mse)        
                    mse_results[collab_type+'-mses'].append(mses)

                    print(f'**** {collab_type} MSEs: {mses} Avg MSE: {mse} ****')
                except Exception as inst:
                    print(type(inst))    # the exception instance
                    print(inst.args)     # arguments stored in .args
                    print(inst)          # __str__ allows args to be printed directly,
                                         # but may be overridden in exception subclasses

    ode_ind_regression_df = get_regression_df(mse_results)
# Out:
# **** trial index 1 ****
#
# Model being initialized...
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde.py:83: The name tf.cholesky is deprecated. Please use tf.linalg.cholesky instead.
#
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde.py:87: The name tf.matrix_triangular_solve is deprecated. Please use tf.linalg.triangular_solve instead.
#
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde_helper.py:95: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Building loss function...
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde_helper.py:135: The name tf.diag is deprecated. Please use tf.linalg.tensor_diag instead.
#
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde_helper.py:135: MultivariateNormalFullCovariance.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_full_covariance) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/contrib/distributions/python/ops/mvn_full_covariance.py:195: MultivariateNormalTriL.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_tril) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/contrib/distributions/python/ops/mvn_tril.py:222: MultivariateNormalLinearOperator.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_linear_operator) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/contrib/distributions/python/ops/mvn_linear_operator.py:199: Normal.__init__ (from tensorflow.python.ops.distributions.normal) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/python/ops/distributions/normal.py:160: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/contrib/distributions/python/ops/mvn_linear_operator.py:201: AffineLinearOperator.__init__ (from tensorflow.contrib.distributions.python.ops.bijectors.affine_linear_operator) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/contrib/distributions/python/ops/bijectors/affine_linear_operator.py:158: _DistributionShape.__init__ (from tensorflow.contrib.distributions.python.ops.shape) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/contrib/distributions/python/ops/mvn_linear_operator.py:205: TransformedDistribution.__init__ (from tensorflow.python.ops.distributions.transformed_distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /home/fengzi/anaconda3/envs/CAL-TF/lib/python3.6/site-packages/tensorflow_core/python/ops/math_ops.py:2509: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde.py:105: MultivariateNormalDiag.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_diag) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# Adam optimizer being initialized...
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde_helper.py:159: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From /home/fengzi/Downloads/codebase/collaborative-active-learning/npde_master/npde_helper.py:160: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00031422 0.01822301]
# signal variance:       3.0334046409120607
# lengthscales:          [0.94935922 1.32759265]
# RMSE over the dimensions is: 4.042510931096123
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00626058 0.00870978]
# signal variance:       2.257332460304492
# lengthscales:          [0.95269059 1.04950168]
# RMSE over the dimensions is: 7.004897877741255
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.01006496 0.00073809]
# signal variance:       2.3847369721498484
# lengthscales:          [0.76336902 1.03753903]
# RMSE over the dimensions is: 11.044435793342352
# **** indiv_greedy_obs MSEs: [4.042510931096123, 7.004897877741255, 11.044435793342352] Avg MSE: 7.363948200726576 ****
# **** trial index 2 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00567648 0.00135132]
# signal variance:       5.148087465216208
# lengthscales:          [1.29186751 1.10661647]
# RMSE over the dimensions is: 3.2090181592693146
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00442563 0.00352321]
# signal variance:       2.4652604146583434
# lengthscales:          [0.73773403 1.33580795]
# RMSE over the dimensions is: 8.265091394012495
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00081491 0.00385079]
# signal variance:       1.9007579267037944
# lengthscales:          [0.98594686 0.71797308]
# RMSE over the dimensions is: 10.750136520276772
# **** indiv_greedy_obs MSEs: [3.2090181592693146, 8.265091394012495, 10.750136520276772] Avg MSE: 7.408082024519527 ****
# **** trial index 3 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00556034 0.0033205 ]
# signal variance:       2.8660508982570696
# lengthscales:          [0.81520525 1.23615604]
# RMSE over the dimensions is: 3.7939577818486914
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00462282 0.00148981]
# signal variance:       2.558046928438533
# lengthscales:          [0.97755583 0.45113333]
# RMSE over the dimensions is: 5.567758228896983
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.01251133 0.01118068]
# signal variance:       1.760128476516213
# lengthscales:          [0.94723843 0.72402322]
# RMSE over the dimensions is: 10.630913816087624
# **** indiv_greedy_obs MSEs: [3.7939577818486914, 5.567758228896983, 10.630913816087624] Avg MSE: 6.664209942277766 ****
# **** trial index 4 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.0004016  0.00172953]
# signal variance:       5.325246871260713
# lengthscales:          [0.5573448  0.93855836]
# RMSE over the dimensions is: 4.394643220130628
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00334392 0.01910298]
# signal variance:       2.2200858061604465
# lengthscales:          [0.6618611  1.44182141]
# RMSE over the dimensions is: 8.368799096561261
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.01126923 0.00891699]
# signal variance:       1.7364342639192223
# lengthscales:          [1.10911949 0.88856991]
# RMSE over the dimensions is: 10.811629094213075
# **** indiv_greedy_obs MSEs: [4.394643220130628, 8.368799096561261, 10.811629094213075] Avg MSE: 7.858357136968322 ****
# **** trial index 5 ****
#
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00069826 0.01492975]
# signal variance:       4.018087720008793
# lengthscales:          [0.75631038 1.21031036]
# RMSE over the dimensions is: 5.531001000887238
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00058731 0.00310157]
# signal variance:       2.19760622501263
# lengthscales:          [0.60060364 1.21572585]
# RMSE over the dimensions is: 4.660090103096185
# Model being initialized...
# Building loss function...
# Adam optimizer being initialized...
# Optimization starts.
# Optimization ends.
# name:                  npode
# noise variance:        [0.00396563 0.00290032]
# signal variance:       1.7210353176622575
# lengthscales:          [0.93170573 0.92599737]
# RMSE over the dimensions is: 10.97789841000935
# **** indiv_greedy_obs MSEs: [5.531001000887238, 4.660090103096185, 10.97789841000935] Avg MSE: 7.056329837997591 ****

# %%
ode_ind_regression_df
# Out:
#       Baselines   Avg MSE   Stderr   Std MSE  Stderr Std
# 0  indiv_greedy  7.270185  0.19833  2.868899    0.080243

# %%
with cwd(oj(results_dir, 'regression_results')):
    ode_ind_regression_df.to_csv('ODE-regression-correction.csv', index=False)
    ode_ind_regression_df.to_latex('ODE-regression-correction.tex', index=False)

# %%
regression_df
# Out:
#   Baselines   Avg MSE    Stderr   Std MSE  Stderr Std
# 0   entropy  2.981224  0.465341  1.157018    0.036469

# %%
regression_df # training iter 1000, for entropy and indi
# Out:
#       Baselines   Avg MSE    Stderr   Std MSE  Stderr Std
# 0       entropy  2.864518  0.430831  1.104927    0.051972
# 1  indiv_greedy  5.179316  0.802955  2.613171    0.137215

# %%
with cwd(oj(results_dir, 'regression_results')):
    regression_df.to_csv('SDE-regression-correction.csv', index=False)
    regression_df.to_latex('SDE-regression-correction.tex', index=False)

# %%
ODE_regression_df
# Out:
#       Baselines   Avg MSE    Stderr   Std MSE  Stderr Std
# 0      greedy_1  5.857746  0.397743  2.359273    0.266774
# 1      greedy_2  6.725795  0.812513  3.805229    1.075850
# 2      greedy_3  6.179537  0.635290  2.072478    0.665395
# 3      greedy_4  5.476039  0.330058  1.987787    0.302376
# 4    greedy_sum  6.212020  0.661704  2.767850    1.249287
# 5  dynamic_beta  5.758070  0.424243  2.077605    0.373631
# 6         joint  5.339084  0.474563  2.125629    0.436403
# 7          rand  6.239905  0.495719  2.178888    0.432880
# 8       entropy  5.171592  0.156638  1.920965    0.151457
# 9  indiv_greedy  6.484443  0.374912  1.281067    0.136480

# %% [markdown]
# ### VDP

# %%
indiv_rand_regression_for_VDP = indiv_rand_regression_df

# %%
VDP_mse_results = deepcopy(mse_results)

# %%
indiv_rand_regression_for_VDP
# Out:
#       Baselines   Avg MSE    Stderr   Std MSE  Stderr Std
# 0  indiv_greedy  6.839020  0.741066  1.858412    0.265737
# 1          rand  4.973591  1.254244  2.457056    0.895329

# %%
with cwd(oj(local_dir, setting)):
    indiv_rand_regression_df.to_csv('VDP_correction.csv', index=False)

# %%
# indiv_regression_df = get_regression_df(mse_results)
indiv_regression_df
# Out:
#       Baselines  Avg MSE    Stderr   Std MSE  Stderr Std
# 0  indiv_greedy  6.83902  0.741066  1.858412    0.265737

# %%
mse_results
# Out:
# defaultdict(list,
#             {'greedy_obs_1-avg-mses': [4.178536317003405,
#               4.305602157058645,
#               2.868588750859472,
#               3.851607596680812,
#               5.1480001667037785],
#              'greedy_obs_1-mses': [[2.2593988882213423,
#                7.560133496191136,
#                2.7160765665977378],
#               [3.655590891935502, 7.222758576876525, 2.038457002363908],
#               [2.2572134940223623, 3.8007284909631096, 2.5478242675929437],
#               [2.623772508328433, 3.4927824561882304, 5.438267825525773],
#               [1.7120316230317485, 10.138245941169346, 3.5937229359102414]],
#              'greedy_obs_2-avg-mses': [4.1246115376366195,
#               4.643293169825471,
#               4.009888615452311,
#               4.359279892610691],
#              'greedy_obs_2-mses': [[2.2619341957503094,
#                7.441289090976445,
#                2.6706113261831033],
#               [3.106127457532123, 7.439960984941314, 3.3837910670029743],
#               [2.3094426003926403, 4.582739874122948, 5.137483371841343],
#               [4.2961310801406745, 4.784866494497222, 3.9968421031941777]],
#              'greedy_obs_3-avg-mses': [3.8803439368609682,
#               4.6542023256061835,
#               2.968789755816945,
#               4.3402821613232945],
#              'greedy_obs_3-mses': [[2.08755619267208,
#                6.655423864549584,
#                2.8980517533612415],
#               [4.076492983234241, 8.04369721126687, 1.8424167823174407],
#               [2.130140146565823, 4.13357255959057, 2.6426565612944426],
#               [3.283246782628636, 6.763101204866206, 2.9744984964750407]],
#              'greedy_obs_4-avg-mses': [3.9074934959009666,
#               4.730217787186983,
#               3.433268780269914,
#               4.720419260059275],
#              'greedy_obs_4-mses': [[2.1776609491636307,
#                6.867276390217125,
#                2.6775431483221452],
#               [3.791931844516783, 8.268486044014427, 2.1302354730297393],
#               [2.6776572087158317, 4.70651390229001, 2.915635229803901],
#               [2.700525103519845, 4.462675130516333, 6.998057546141647]],
#              'greedy_sum_obs-avg-mses': [4.061784173740402,
#               4.9740955661904644,
#               3.3312987179495694,
#               3.472606954814185],
#              'greedy_sum_obs-mses': [[2.2663611124122496,
#                7.132224499700959,
#                2.786766909107997],
#               [4.315617727925617, 6.979010762949061, 3.6276582076967157],
#               [2.406190418663604, 4.176289691902994, 3.4114160432821095],
#               [2.725462924543759, 3.9503289278101175, 3.742029012088679]],
#              'dynamic_beta_obs-avg-mses': [4.343215354787309,
#               3.819967169191913,
#               3.1676683165120703,
#               3.994408331985957],
#              'dynamic_beta_obs-mses': [[2.121749495292021,
#                8.146438332858562,
#                2.7614582362113436],
#               [3.6423720806244173, 5.453761924276403, 2.3637675026749196],
#               [2.2880615165396234, 4.4703108041624535, 2.7446326288341343],
#               [3.3868287317467485, 4.338878241469001, 4.257518022742121]],
#              'joint_obs-avg-mses': [4.142191588448568,
#               4.156182681275967,
#               2.9960771459035205,
#               4.262828942106008],
#              'joint_obs-mses': [[2.247868456899366,
#                7.50485897321648,
#                2.673847335229857],
#               [3.0736898070658016, 6.493790407707974, 2.901067829054123],
#               [2.345002158071919, 4.17597109252603, 2.4672581871126122],
#               [5.016506501893241, 5.021465734597145, 2.750514589827638]],
#              'rand_obs-avg-mses': [4.220151103473373,
#               3.5617876620526436,
#               2.9597699315835513,
#               2.912154925624779],
#              'rand_obs-mses': [[2.077718080982347,
#                8.35578392859609,
#                2.226951300841684],
#               [3.4504448895337854, 5.1086831521416025, 2.1262349444825435],
#               [2.2451121399962144, 3.871478436038023, 2.7627192187164153],
#               [2.580703960798584, 4.203933367478642, 1.9518274485971112]],
#              'entropy_obs-avg-mses': [4.649901106905428,
#               4.649300127104264,
#               3.098202044917953,
#               5.493464080509275],
#              'entropy_obs-mses': [[2.213033030039715,
#                8.47031768434467,
#                3.2663526063318993],
#               [3.92318309284247, 7.888649143791107, 2.136068144679217],
#               [2.3565896613038664, 4.3367588907504855, 2.6012575826995077],
#               [4.127992066459512, 4.902020109131356, 7.450380065936957]],
#              'indiv_greedy_obs-avg-mses': [5.276575478681833,
#               7.245973460827789,
#               6.780558548921639,
#               7.882738649452617],
#              'indiv_greedy_obs-mses': [[4.507582228421915,
#                8.895293119214099,
#                2.426851088409484],
#               [12.105060058101998, 7.4870672502492575, 2.145793074132109],
#               [10.697877550566734, 7.192418273727554, 2.4513798224706314],
#               [14.015990238258247, 6.126535891141112, 3.50568981895849]]})

# %% [markdown]
# #### all the share the same target - time [0,8]

# %%
de_regression_df
# Out:
#       Baselines   Avg MSE  Stderr   Std MSE  Stderr Std
# 0      greedy_1  2.756342     NaN  2.756342         NaN
# 1      greedy_2  2.398316     NaN  2.398316         NaN
# 2      greedy_3  3.438041     NaN  3.438041         NaN
# 3      greedy_4  3.627456     NaN  3.627456         NaN
# 4    greedy_sum  2.944234     NaN  2.944234         NaN
# 5  dynamic_beta  3.803732     NaN  3.803732         NaN
# 6         joint  2.785771     NaN  2.785771         NaN
# 7          rand  2.650305     NaN  2.650305         NaN
# 8       entropy  2.376445     NaN  2.376445         NaN

# %%
# with cwd(oj(results_dir, setting)):
#     de_regression_df.to_latex('regression_results.tex',index=False)
#     de_regression_df.to_csv('regression_results.csv',index=False)
